# %%
import Segmentation2
import Prediction
import datetime

for i in range(50):
    start = datetime.datetime.now()
    Segmentation.data_processing()
    print(Prediction.predict())
    end = datetime.datetime.now()
    print(end - start)
# Out:
# sidestep
# 0:00:01.866277
# sidestep
# 0:00:01.922834
# sidestep
# 0:00:01.895935
# sidestep
# 0:00:01.906438
# sidestep
# 0:00:02.054739
# sidestep
# 0:00:02.125296
# sidestep
# 0:00:02.349729
# sidestep
# 0:00:02.136411
# sidestep
# 0:00:02.031597
# sidestep
# 0:00:02.011299
# sidestep
# 0:00:01.924686
# sidestep
# 0:00:01.963793
# sidestep
# 0:00:01.945761
# sidestep
# 0:00:01.875197
# sidestep
# 0:00:02.016925
# sidestep
# 0:00:02.120605
# sidestep
# 0:00:02.098126
# sidestep
# 0:00:01.930187
# sidestep
# 0:00:02.000980
# sidestep
# 0:00:02.134326
# sidestep
# 0:00:02.013896
# sidestep
# 0:00:01.936828
# sidestep
# 0:00:02.022249
# sidestep
# 0:00:01.929895
# sidestep
# 0:00:01.924859
# sidestep
# 0:00:02.084429
# sidestep
# 0:00:02.016611
# sidestep
# 0:00:02.036558
# sidestep
# 0:00:02.150290
# sidestep
# 0:00:02.136261
# sidestep
# 0:00:02.113347
# sidestep
# 0:00:02.093407
# sidestep
# 0:00:01.970734
# sidestep
# 0:00:02.119338
# sidestep
# 0:00:01.854046
# sidestep
# ...

# %%
import pandas as pd

sidestep = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\sidestep_dataset.csv')
sidestep = sidestep.drop(['activity'], axis=1)
sidestep.to_csv(r'C:\Users\User\Desktop\chicken_dataset.csv', index=False)
