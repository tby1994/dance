# %%
# data analysis
import pandas as pd
import DataProcessing

chicken_data = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\chicken_dataset.csv')
number7_data = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\number7_dataset.csv')
sidestep_data = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\sidestep_dataset.csv')
turnclap_data = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\turnclap_dataset.csv')
wiper_data = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\wiper_dataset.csv')

# bobby_chicken = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\bobby\chicken.csv')
# bobby_number7 = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\bobby\number7.csv')
# bobby_sidestep = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\bobby\sidestep.csv')
# bobby_turnclap = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\bobby\turnclap.csv')
# bobby_turnclap2 = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\bobby\turnclap2.csv')
# bobby_wiper = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\bobby\wiper.csv')

# beeyee_chicken = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\beeyee\chicken.csv')
# beeyee_number7 = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\beeyee\number7.csv')
# beeyee_sidestep = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\beeyee\sidestep.csv')
# beeyee_turnclap = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\beeyee\turnclap.csv')
# beeyee_turnclap2 = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\beeyee\turnclap2.csv')
# beeyee_wiper = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\beeyee\wiper.csv')

henry_chicken = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\henry\2\chicken.csv')
henry_number7 = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\henry\2\number7-1.csv')
henry_number7_2 = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\henry\2\number7-2.csv')
henry_sidestep = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\henry\2\sidestep.csv')
henry_turnclap1 = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\henry\2\turnclap1.csv')
henry_turnclap2 = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\henry\2\turnclap2.csv')
henry_turnclap3 = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\henry\2\turnclap3.csv')
henry_turnclap4 = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\henry\2\turnclap4.csv')
henry_turnclap5 = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\henry\2\turnclap5.csv')
henry_wiper = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\henry\2\wiper.csv')

# kabir_chicken = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\kabir\chicken.csv')
# kabir_number7 = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\kabir\number7.csv')
# kabir_sidestep = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\kabir\sidestep.csv')
# kabir_turnclap = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\kabir\turnclap.csv')
# kabir_turnclap2 = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\kabir\turnclap2.csv')
# kabir_wiper = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\kabir\wiper.csv')

# zech_chicken = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\zech\chicken.csv')
# zech_number7 = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\zech\number7.csv')
# zech_sidestep = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\zech\sidestep.csv')
# zech_turnclap = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\zech\turnclap.csv')
# zech_turnclap2 = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\zech\turnclap2.csv')
# zech_wiper = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\zech\wiper.csv')

hongjing_chicken = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\hongjing\2\chicken.csv')
hongjing_number7 = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\hongjing\2\number7.csv')
hongjing_sidestep = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\hongjing\2\sidestep.csv')
hongjing_turnclap1 = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\hongjing\2\turnclap1.csv')
hongjing_turnclap2 = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\hongjing\2\turnclap2.csv')
hongjing_turnclap3 = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\hongjing\2\turnclap3.csv')
hongjing_turnclap4 = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\hongjing\2\turnclap4.csv')
hongjing_turnclap5 = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\hongjing\2\turnclap5.csv')
hongjing_wiper = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\hongjing\2\wiper.csv')

# frames_chicken = [bobby_chicken, beeyee_chicken, henry_chicken, kabir_chicken, zech_chicken, hongjing_chicken]
# frames_number7 = [bobby_number7, beeyee_number7, henry_chicken, kabir_number7, zech_number7, hongjing_number7]
# frames_sidestep = [bobby_sidestep, beeyee_sidestep, henry_sidestep, kabir_sidestep, zech_sidestep, hongjing_sidestep]
# frames_turnclap = [bobby_turnclap, bobby_turnclap2, beeyee_turnclap, beeyee_turnclap2, henry_turnclap1,
#                    henry_turnclap2, henry_turnclap3, henry_turnclap4, zech_turnclap, zech_turnclap2,]
# frames_wiper = [bobby_wiper, beeyee_wiper, henry_wiper, kabir_wiper, zech_wiper, hongjing_wiper]
chicken_data = chicken_data.drop(['activity'], axis=1).copy()
number7_data = number7_data.drop(['activity'], axis=1).copy()
sidestep_data = sidestep_data.drop(['activity'], axis=1).copy()
turnclap_data = turnclap_data.drop(['activity'], axis=1).copy()
wiper_data = wiper_data.drop(['activity'], axis=1).copy()

frames_chicken = [chicken_data, henry_chicken, hongjing_chicken]
frames_number7 = [number7_data, henry_number7_1, henry_number7_2, hongjing_number7]
frames_sidestep = [sidestep_data, henry_sidestep, hongjing_sidestep]
frames_turnclap = [turnclap_data, henry_turnclap1, henry_turnclap2, henry_turnclap3, henry_turnclap4, 
                   henry_turnclap5, hongjing_turnclap1, hongjing_turnclap2, hongjing_turnclap3, hongjing_turnclap4,
                    hongjing_turnclap5]
frames_wiper = [wiper_data, henry_wiper, hongjing_wiper]

chicken_data = pd.concat(frames_chicken)
number7_data = pd.concat(frames_number7)
sidestep_data = pd.concat(frames_sidestep)
turnclap_data = pd.concat(frames_turnclap)
wiper_data = pd.concat(frames_wiper)

chicken_data['activity'] = 1;
number7_data['activity'] = 2;
sidestep_data['activity'] = 3;
turnclap_data['activity'] = 4;
wiper_data['activity'] = 5;

chicken_data.to_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\chicken_dataset.csv', index=False)
number7_data.to_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\number7_dataset.csv', index=False)
sidestep_data.to_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\sidestep_dataset.csv', index=False)
turnclap_data.to_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\turnclap_dataset.csv', index=False)
wiper_data.to_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\wiper_dataset.csv', index=False)

# frames_result = [chicken_data, number7_data, sidestep_data, turnclap_data, wiper_data]

# result = pd.concat(frames_result)

# result = result.drop(['voltage', 'current', 'power', 'energy'], axis = 1).copy()

print('done')

#result.to_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\raw data\dataset.csv', index=False)
# Out:
# done

# %%
import pandas as pd
chicken = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\extracted data\chicken_extracted_dataset.csv')
number7 = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\extracted data\number7_extracted_dataset.csv')
sidestep = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\extracted data\sidestep_extracted_dataset.csv')
turnclap = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\extracted data\turnclap_extracted_dataset.csv')
wiper = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\extracted data\wiper_extracted_dataset.csv')

frames_result = [chicken, number7, sidestep, turnclap, wiper]

result = pd.concat(frames_result)
# result = result.drop(['voltage', 'current', 'power', 'energy'], axis = 1).copy()
result.to_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\extracted data\extracted_dataset.csv', index=False)
print(chicken.info())
print(number7.info())
print(sidestep.info())
print(turnclap.info())
print(wiper.info())
print("done")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2804 entries, 0 to 2803
# Data columns (total 55 columns):
# mean_AcX 1    2804 non-null float64
# mean_AcX 2    2804 non-null float64
# mean_AcX 3    2804 non-null float64
# mean_AcY 1    2804 non-null float64
# mean_AcY 2    2804 non-null float64
# mean_AcY 3    2804 non-null float64
# mean_AcZ 1    2804 non-null float64
# mean_AcZ 2    2804 non-null float64
# mean_AcZ 3    2804 non-null float64
# mean_GyX 1    2804 non-null float64
# mean_GyX 2    2804 non-null float64
# mean_GyX 3    2804 non-null float64
# mean_GyY 1    2804 non-null float64
# mean_GyY 2    2804 non-null float64
# mean_GyY 3    2804 non-null float64
# mean_GyZ 1    2804 non-null float64
# mean_GyZ 2    2804 non-null float64
# mean_GyZ 3    2804 non-null float64
# std_AcX 1     2804 non-null float64
# std_AcX 2     2804 non-null float64
# std_AcX 3     2804 non-null float64
# std_AcY 1     2804 non-null float64
# std_AcY 2     2804 non-null float64
# std_AcY 3     2804 non-null float64
# std_AcZ 1     2804 non-null float64
# std_AcZ 2     2804 non-null float64
# std_AcZ 3     2804 non-null float64
# std_GyX 1     2804 non-null float64
# std_GyX 2     2804 non-null float64
# std_GyX 3     2804 non-null float64
# std_GyY 1     2804 non-null float64
# std_GyY 2     2804 non-null float64
# std_GyY 3     2804 non-null float64
# std_GyZ 1     2804 non-null float64
# std_GyZ 2     2804 non-null float64
# std_GyZ 3     2804 non-null float64
# max_AcX 1     2804 non-null float64
# max_AcX 2     2804 non-null float64
# max_AcX 3     2804 non-null float64
# max_AcY 1     2804 non-null float64
# max_AcY 2     2804 non-null float64
# max_AcY 3     2804 non-null float64
# max_AcZ 1     2804 non-null float64
# max_AcZ 2     2804 non-null float64
# max_AcZ 3     2804 non-null float64
# max_GyX 1     2804 non-null float64
# max_GyX 2     2804 non-null float64
# max_GyX 3     2804 non-null float64
# max_GyY 1     2804 non-null float64
# max_GyY 2     2804 non-null float64
# max_GyY 3     2804 non-null float64
# max_GyZ 1     2804 non-null float64
# max_GyZ 2     2804 non-null float64
# max_GyZ 3     2804 non-null float64
# activity      2804 non-null int64
# dtypes: float64(54), int64(1)
# memory usage: 1.2 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2692 entries, 0 to 2691
# Data columns (total 55 columns):
# mean_AcX 1    2692 non-null float64
# mean_AcX 2    2692 non-null float64
# mean_AcX 3    2692 non-null float64
# mean_AcY 1    2692 non-null float64
# mean_AcY 2    2692 non-null float64
# mean_AcY 3    2692 non-null float64
# mean_AcZ 1    2692 non-null float64
# mean_AcZ 2    2692 non-null float64
# mean_AcZ 3    2692 non-null float64
# mean_GyX 1    2692 non-null float64
# mean_GyX 2    2692 non-null float64
# mean_GyX 3    2692 non-null float64
# mean_GyY 1    2692 non-null float64
# mean_GyY 2    2692 non-null float64
# mean_GyY 3    2692 non-null float64
# mean_GyZ 1    2692 non-null float64
# mean_GyZ 2    2692 non-null float64
# mean_GyZ 3    2692 non-null float64
# std_AcX 1     2692 non-null float64
# std_AcX 2     2692 non-null float64
# std_AcX 3     2692 non-null float64
# std_AcY 1     2692 non-null float64
# std_AcY 2     2692 non-null float64
# std_AcY 3     2692 non-null float64
# std_AcZ 1     2692 non-null float64
# std_AcZ 2     2692 non-null float64
# std_AcZ 3     2692 non-null float64
# std_GyX 1     2692 non-null float64
# std_GyX 2     2692 non-null float64
# std_GyX 3     2692 non-null float64
# std_GyY 1     2692 non-null float64
# std_GyY 2     2692 non-null float64
# std_GyY 3     2692 non-null float64
# std_GyZ 1     2692 non-null float64
# std_GyZ 2     2692 non-null float64
# std_GyZ 3     2692 non-null float64
# max_AcX 1     2692 non-null float64
# max_AcX 2     2692 non-null float64
# max_AcX 3     2692 non-null float64
# max_AcY 1     2692 non-null float64
# max_AcY 2     2692 non-null float64
# max_AcY 3     2692 non-null float64
# max_AcZ 1     2692 non-null float64
# max_AcZ 2     2692 non-null float64
# max_AcZ 3     2692 non-null float64
# max_GyX 1     2692 non-null float64
# max_GyX 2     2692 non-null float64
# max_GyX 3     2692 non-null float64
# max_GyY 1     2692 non-null float64
# max_GyY 2     2692 non-null float64
# max_GyY 3     2692 non-null float64
# max_GyZ 1     2692 non-null float64
# max_GyZ 2     2692 non-null float64
# max_GyZ 3     2692 non-null float64
# activity      2692 non-null int64
# dtypes: float64(54), int64(1)
# memory usage: 1.1 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2744 entries, 0 to 2743
# Data columns (total 55 columns):
# mean_AcX 1    2744 non-null float64
# mean_AcX 2    2744 non-null float64
# mean_AcX 3    2744 non-null float64
# mean_AcY 1    2744 non-null float64
# mean_AcY 2    2744 non-null float64
# mean_AcY 3    2744 non-null float64
# mean_AcZ 1    2744 non-null float64
# mean_AcZ 2    2744 non-null float64
# mean_AcZ 3    2744 non-null float64
# mean_GyX 1    2744 non-null float64
# mean_GyX 2    2744 non-null float64
# mean_GyX 3    2744 non-null float64
# mean_GyY 1    2744 non-null float64
# mean_GyY 2    2744 non-null float64
# mean_GyY 3    2744 non-null float64
# mean_GyZ 1    2744 non-null float64
# mean_GyZ 2    2744 non-null float64
# mean_GyZ 3    2744 non-null float64
# std_AcX 1     2744 non-null float64
# std_AcX 2     2744 non-null float64
# std_AcX 3     2744 non-null float64
# std_AcY 1     2744 non-null float64
# std_AcY 2     2744 non-null float64
# std_AcY 3     2744 non-null float64
# std_AcZ 1     2744 non-null float64
# std_AcZ 2     2744 non-null float64
# std_AcZ 3     2744 non-null float64
# std_GyX 1     2744 non-null float64
# std_GyX 2     2744 non-null float64
# std_GyX 3     2744 non-null float64
# std_GyY 1     2744 non-null float64
# std_GyY 2     2744 non-null float64
# std_GyY 3     2744 non-null float64
# std_GyZ 1     2744 non-null float64
# std_GyZ 2     2744 non-null float64
# std_GyZ 3     2744 non-null float64
# max_AcX 1     2744 non-null float64
# max_AcX 2     2744 non-null float64
# max_AcX 3     2744 non-null float64
# max_AcY 1     2744 non-null float64
# max_AcY 2     2744 non-null float64
# max_AcY 3     2744 non-null float64
# max_AcZ 1     2744 non-null float64
# max_AcZ 2     2744 non-null float64
# max_AcZ 3     2744 non-null float64
# max_GyX 1     2744 non-null float64
# max_GyX 2     2744 non-null float64
# max_GyX 3     2744 non-null float64
# max_GyY 1     2744 non-null float64
# max_GyY 2     2744 non-null float64
# max_GyY 3     2744 non-null float64
# max_GyZ 1     2744 non-null float64
# max_GyZ 2     2744 non-null float64
# max_GyZ 3     2744 non-null float64
# activity      2744 non-null int64
# dtypes: float64(54), int64(1)
# memory usage: 1.2 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2680 entries, 0 to 2679
# Data columns (total 55 columns):
# mean_AcX 1    2680 non-null float64
# mean_AcX 2    2680 non-null float64
# mean_AcX 3    2680 non-null float64
# mean_AcY 1    2680 non-null float64
# mean_AcY 2    2680 non-null float64
# mean_AcY 3    2680 non-null float64
# mean_AcZ 1    2680 non-null float64
# mean_AcZ 2    2680 non-null float64
# mean_AcZ 3    2680 non-null float64
# mean_GyX 1    2680 non-null float64
# mean_GyX 2    2680 non-null float64
# mean_GyX 3    2680 non-null float64
# mean_GyY 1    2680 non-null float64
# mean_GyY 2    2680 non-null float64
# mean_GyY 3    2680 non-null float64
# mean_GyZ 1    2680 non-null float64
# mean_GyZ 2    2680 non-null float64
# mean_GyZ 3    2680 non-null float64
# std_AcX 1     2680 non-null float64
# std_AcX 2     2680 non-null float64
# std_AcX 3     2680 non-null float64
# std_AcY 1     2680 non-null float64
# std_AcY 2     2680 non-null float64
# std_AcY 3     2680 non-null float64
# std_AcZ 1     2680 non-null float64
# std_AcZ 2     2680 non-null float64
# std_AcZ 3     2680 non-null float64
# std_GyX 1     2680 non-null float64
# std_GyX 2     2680 non-null float64
# std_GyX 3     2680 non-null float64
# std_GyY 1     2680 non-null float64
# std_GyY 2     2680 non-null float64
# std_GyY 3     2680 non-null float64
# std_GyZ 1     2680 non-null float64
# std_GyZ 2     2680 non-null float64
# std_GyZ 3     2680 non-null float64
# max_AcX 1     2680 non-null float64
# max_AcX 2     2680 non-null float64
# max_AcX 3     2680 non-null float64
# max_AcY 1     2680 non-null float64
# max_AcY 2     2680 non-null float64
# max_AcY 3     2680 non-null float64
# max_AcZ 1     2680 non-null float64
# max_AcZ 2     2680 non-null float64
# max_AcZ 3     2680 non-null float64
# max_GyX 1     2680 non-null float64
# max_GyX 2     2680 non-null float64
# max_GyX 3     2680 non-null float64
# max_GyY 1     2680 non-null float64
# max_GyY 2     2680 non-null float64
# max_GyY 3     2680 non-null float64
# max_GyZ 1     2680 non-null float64
# max_GyZ 2     2680 non-null float64
# max_GyZ 3     2680 non-null float64
# activity      2680 non-null int64
# dtypes: float64(54), int64(1)
# memory usage: 1.1 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2720 entries, 0 to 2719
# Data columns (total 55 columns):
# mean_AcX 1    2720 non-null float64
# mean_AcX 2    2720 non-null float64
# mean_AcX 3    2720 non-null float64
# mean_AcY 1    2720 non-null float64
# mean_AcY 2    2720 non-null float64
# mean_AcY 3    2720 non-null float64
# mean_AcZ 1    2720 non-null float64
# mean_AcZ 2    2720 non-null float64
# mean_AcZ 3    2720 non-null float64
# mean_GyX 1    2720 non-null float64
# mean_GyX 2    2720 non-null float64
# mean_GyX 3    2720 non-null float64
# mean_GyY 1    2720 non-null float64
# mean_GyY 2    2720 non-null float64
# mean_GyY 3    2720 non-null float64
# mean_GyZ 1    2720 non-null float64
# mean_GyZ 2    2720 non-null float64
# mean_GyZ 3    2720 non-null float64
# std_AcX 1     2720 non-null float64
# std_AcX 2     2720 non-null float64
# std_AcX 3     2720 non-null float64
# std_AcY 1     2720 non-null float64
# std_AcY 2     2720 non-null float64
# std_AcY 3     2720 non-null float64
# std_AcZ 1     2720 non-null float64
# std_AcZ 2     2720 non-null float64
# std_AcZ 3     2720 non-null float64
# std_GyX 1     2720 non-null float64
# std_GyX 2     2720 non-null float64
# std_GyX 3     2720 non-null float64
# std_GyY 1     2720 non-null float64
# std_GyY 2     2720 non-null float64
# std_GyY 3     2720 non-null float64
# std_GyZ 1     2720 non-null float64
# std_GyZ 2     2720 non-null float64
# std_GyZ 3     2720 non-null float64
# max_AcX 1     2720 non-null float64
# max_AcX 2     2720 non-null float64
# max_AcX 3     2720 non-null float64
# max_AcY 1     2720 non-null float64
# max_AcY 2     2720 non-null float64
# max_AcY 3     2720 non-null float64
# max_AcZ 1     2720 non-null float64
# max_AcZ 2     2720 non-null float64
# max_AcZ 3     2720 non-null float64
# max_GyX 1     2720 non-null float64
# max_GyX 2     2720 non-null float64
# max_GyX 3     2720 non-null float64
# max_GyY 1     2720 non-null float64
# max_GyY 2     2720 non-null float64
# max_GyY 3     2720 non-null float64
# max_GyZ 1     2720 non-null float64
# max_GyZ 2     2720 non-null float64
# max_GyZ 3     2720 non-null float64
# activity      2720 non-null int64
# dtypes: float64(54), int64(1)
# memory usage: 1.1 MB
# None
# done
