# %%
# data analysis
import pandas as pd

# split train and test data
from sklearn.model_selection import train_test_split

# Neural Network model
from sklearn.neural_network import MLPClassifier

from sklearn.svm import SVC

from sklearn.ensemble import RandomForestClassifier

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# Confusion marix to evaluate the model
from sklearn.metrics import classification_report,confusion_matrix

# Evalute the speed of model
import datetime

# Exportation of  model
import pickle

extracted_data = pd.read_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\extracted data\extracted_dataset.csv')

X = extracted_data.drop(['activity'], axis = 1)
y = extracted_data['activity'].copy()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1)

start_time = datetime.datetime.now()

mlp = MLPClassifier(hidden_layer_sizes = (45, 36, 27, 18, 9))
mlp.fit(X_train, y_train)

end_time = datetime.datetime.now()
print("The training accuracy for Neural Network is ", mlp.score(X_train, y_train))
print("The testing accuracy for Neural Network is ", mlp.score(X_test, y_test))
time_taken = end_time - start_time
print("time taken = ", time_taken)

svc = SVC(gamma='scale')
svc.fit(X_train, y_train)
print("The training accuracy for Support Vector Machines is ", svc.score(X_train, y_train))
print("The testing accuracy for Support Vector Machines is ", svc.score(X_test, y_test))

# Model 3: Random Forestry
random_forest = RandomForestClassifier(n_estimators=60)
random_forest.fit(X_train, y_train)
print("The training accuracy for Random Forestry is ", random_forest.score(X_train, y_train))
print("The testing accuracy for Random Forestry is ", random_forest.score(X_test, y_test))

predictions = mlp.predict(X_test)

cm = confusion_matrix(y_test, predictions)

print(cm)

print(confusion_matrix(y_test, svc.predict(X_test)))
print(confusion_matrix(y_test, random_forest.predict(X_test)))
print(classification_report(y_test,predictions))

start_time = datetime.datetime.now()
# export model
filename_mlp = "Neural_Network_Model.sav"
pickle.dump(mlp, open(filename_mlp, 'wb'))

filename_svm = "SVM.sav"
pickle.dump(svc, open(filename_svm, 'wb'))

filename_rd = "RD.sav"
pickle.dump(random_forest, open(filename_rd, 'wb'))

loaded_model = pickle.load(open(filename_mlp, 'rb'))
print("The testing accuracy for imported Neural Network is ", loaded_model.score(X_test, y_test))
predictions = loaded_model.predict(X_test)

mapping = { 1 : 'chicken', 2 : 'number7', 3 : 'sidestep', 4 : 'turnclap', 5 : 'wiper'}
output = pd.DataFrame({'activity' : predictions})
output = output.replace({'activity': mapping})

print(output.activity.mode()[0])

end_time = datetime.datetime.now()
time_taken = end_time - start_time
print("time taken = ", time_taken)
# Out:
# The training accuracy for Neural Network is  1.0
# The testing accuracy for Neural Network is  0.9985119047619048
# time taken =  0:00:13.537169
# The training accuracy for Support Vector Machines is  0.9988147739801544
# The testing accuracy for Support Vector Machines is  0.9992559523809523
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-33786ac7c440> in <module>()
#      49 # Model 3: Random Forestry
#      50 random_forest = RandomForestClassifier(n_estimators=1000)
# ---> 51 random_forest.fit(X_train, y_train)
#      52 print("The training accuracy for Random Forestry is ", random_forest.score(X_train, y_train))
#      53 print("The testing accuracy for Random Forestry is ", random_forest.score(X_test, y_test))
#
# ~\Anaconda3_32bit\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     333                     t, self, X, y, sample_weight, i, len(trees),
#     334                     verbose=self.verbose, class_weight=self.class_weight)
# --> 335                 for i, t in enumerate(trees))
#     336
#     337             # Collect newly grown trees
#
# ~\Anaconda3_32bit\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self, iterable)
#     984                 self._iterating = self._original_iterator is not None
#     985
# --> 986             while self.dispatch_one_batch(iterator):
#     987                 pass
#     988
#
# ~\Anaconda3_32bit\lib\site-packages\sklearn\externals\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     823                 return False
#     824             else:
# --> 825                 self._dispatch(tasks)
#     826                 return True
#     827
#
# ~\Anaconda3_32bit\lib\site-packages\sklearn\externals\joblib\parallel.py in _dispatch(self, batch)
#     780         with self._lock:
#     781             job_idx = len(self._jobs)
# --> 782             job = self._backend.apply_async(batch, callback=cb)
#     783             # A job can complete so quickly than its callback is
#     784             # called before we get here, causing self._jobs to
#
# ~\Anaconda3_32bit\lib\site-packages\sklearn\externals\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~\Anaconda3_32bit\lib\site-packages\sklearn\externals\joblib\_parallel_backends.py in __init__(self, batch)
#     543         # Don't delay the application, to avoid keeping the input
#     544         # arguments in memory
# --> 545         self.results = batch()
#     546
#     547     def get(self):
#
# ~\Anaconda3_32bit\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self)
#     259         with parallel_backend(self._backend):
#     260             return [func(*args, **kwargs)
# --> 261                     for func, args, kwargs in self.items]
#     262
#     263     def __len__(self):
#
# ~\Anaconda3_32bit\lib\site-packages\sklearn\externals\joblib\parallel.py in <listcomp>(.0)
#     259         with parallel_backend(self._backend):
#     260             return [func(*args, **kwargs)
# --> 261                     for func, args, kwargs in self.items]
#     262
#     263     def __len__(self):
#
# ~\Anaconda3_32bit\lib\site-packages\sklearn\ensemble\forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight)
#     119             curr_sample_weight *= compute_sample_weight('balanced', y, indices)
#     120
# --> 121         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     122     else:
#     123         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# ~\Anaconda3_32bit\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     797             sample_weight=sample_weight,
#     798             check_input=check_input,
# --> 799             X_idx_sorted=X_idx_sorted)
#     800         return self
#     801
#
# ~\Anaconda3_32bit\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     363                                            min_impurity_split)
#     364
# --> 365         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     366
#     367         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
a = extracted_data.head(5).copy()
a = a.drop(['activity'], axis=1)
a.to_csv(r'C:\Users\User\Desktop\Study\Year 3\Sem 1\CG3002\DanceProject\Machine Learning\extracted data\test_dataset.csv', index=False)
a
# Out:
#    mean_AcX 1  mean_AcX 2  mean_AcX 3  mean_AcY 1  mean_AcY 2  mean_AcY 3  \
# 0    0.951043    0.927435   -0.451409    0.664003   -0.524674   -0.099512
# 1    0.828513    0.776466   -0.426775    0.561727   -0.645073   -0.148524
# 2    0.859740    0.697900   -0.327648    0.562882   -0.916189   -0.228260
# 3    0.782341    0.535010   -0.308962    0.698875   -0.740033   -0.312577
# 4    0.654583    0.551655   -0.128157    0.621135   -0.989829   -0.424468
#
#    mean_AcZ 1  mean_AcZ 2  mean_AcZ 3  mean_GyX 1    ...      std_AcZ 3  \
# 0   -0.389624   -0.629469   -0.016309   -0.041745    ...       0.293594
# 1   -0.446945   -0.539846   -0.026970   -0.037491    ...       0.316625
# 2   -0.299735   -0.396465   -0.011650   -0.032491    ...       0.346394
# 3   -0.320222   -0.480491   -0.028975    0.015598    ...       0.372206
# 4   -0.317007   -0.385177   -0.012230    0.071758    ...       0.376877
#
#    std_GyX 1  std_GyX 2  std_GyX 3  std_GyY 1  std_GyY 2  std_GyY 3  \
# 0   0.718759   0.819632   0.944258   0.862839   0.542572   0.582300
# 1   0.740978   0.859547   1.022605   0.936302   0.598981   0.611990
# 2   0.725412   0.910424   1.064072   0.995038   0.590413   0.641700
# 3   0.707981   0.895050   1.095297   0.989493   0.653171   0.610295
# 4   0.685142   0.818781   1.023249   0.969951   0.592112   0.864472
#
#    std_GyZ 1  std_GyZ 2  std_GyZ 3
